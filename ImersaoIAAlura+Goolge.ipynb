# %% [markdown]
# <a href="https://colab.research.google.com/github/fabiotgolo/ProjetoImersaoAlura/blob/main/ImersaoIAAlura%2BGoolge.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q -U google-generativeai

# %%
# Importações e configurações iniciais

import numpy as np
import pandas as pd
import google.generativeai as genai

from google.colab import userdata
api_key = userdata.get('SECRET_KEY')
genai.configure(api_key=api_key)

# %%
for m in genai.list_models():
  if 'embedContent' in m.supported_generation_methods:
    print(m.name)
# Out:
# models/embedding-001
# models/text-embedding-004

# %%
title = "A próxima geração de IA para desenvolvedores e Google Workspace"
sample_text = ("Título: A próxima geração de IA para desenvolvedores e o Google Workspace"
    "\n"
    "Artigo completo:\n"
    "\n"
    "Gemini API e Google AI Studio: uma maneira acessível de explorar e criar protótipos com aplicativos generativos de IA")

model = 'models/embedding-001'
embedding = genai.embed_content(model="models/embedding-001",
                                content=sample_text,
                                task_type="retrieval_document",
                                title=title)

print(embedding)
# Out:
# {'embedding': [0.05030521, -0.035547726, -0.022365583, 0.020420885, 0.06619298, -0.0049817995, -0.029137805, -0.016434198, 0.060912218, 0.065356284, 0.01511428, 0.016915554, -0.04471576, -0.022297753, 0.0054538054, -0.02023794, 0.019634994, -0.011932298, -0.034369837, -0.005230974, 0.0121585885, 0.010193448, -0.031582583, -0.06591023, -0.018254796, 0.020398147, 0.013204382, -0.03703664, -0.030708993, 0.02932178, -0.048887406, 0.050836477, -0.035615582, 0.015414437, -0.03849916, -0.034793667, -0.027117884, -0.04542623, -0.0038519253, -0.002237399, 0.003035803, -0.08599902, -0.010510885, 0.026055232, -0.007402526, -0.025485905, 0.043822896, 0.04542552, 0.012509869, -0.05765129, 0.023758402, 0.022070287, 0.07479265, -0.04100853, -0.0008982605, -0.009938924, 0.022114534, -0.03279263, 0.020490283, -0.0026151398, 0.0013906044, 0.020898132, -0.014540928, 0.05557214, 0.020625183, -0.056253027, -0.043218043, -0.0029367476, 0.0070332177, 0.051757332, 0.008675726, 0.0141036175, 0.054835595, -0.
# ...

# %%
DOCUMENT1 = {
    "title": "Erick Prados Pereira",
    "content": "Este projeto é um projeto real que foi feito para um evento na cidade de Uberaba. Este sistema simples consiste em ser um totem para coleta de inscrições + um chat bot personalizado. O usuário inicia o sistema, preenche as informações de inscrição, como (telefone, email e nome) e depois de confirmar uma cópia destes dados é salva no banco de dados MySQL e também é enviado um email com estes dados (se estiver rodando em windows), após a inscrição abre-se a tela do chat bot, que foi previamente ensinada com informações da empresa, e então o usuário pode perguntar qualquer coisa relacionada a empresa, tirar suas dúvidas, etc..."}

DOCUMENT2 = {
    "title": "TouTela sensível ao toquechscreen",
    "content": "Uma aplicação para gerar um roteiro de viagem personalizado de acordo com o destino e quantidade de dias."}

DOCUMENT3 = {
    "title": "David Duarte Muniz",
    "content": "Projeto de um site de Biologia com informações importantes sobre as espécies de polvos (Octopus). Vale destacar que o foco do site é apenas destacar a importância dos polvos no ecossistema marinho, e também os seus comportamentos interessantes."}

DOCUMENT4 = {
    "title": "José Augusto Faria de Sousa",
    "content": "Este projeto é um corretor de códigos JAVA, que identifica erros no código e sugere correções. O sistema mostra o erro e como arrumar. Link do projeto no GitHub: https://github.com/JoseAugustoFS/Corretor-de-codigos-JAVA"
}

DOCUMENT5 = {
    "title": "Victor Verdoodt",
    "content": "O projeto 'Disaster Response Coordinator' é uma aplicação baseada em inteligência artificial que utiliza a API do Gemini para oferecer suporte e coordenação durante situações de desastre. Este sistema interativo está projetado para ajudar indivíduos afetados por desastres naturais ou emergências, fornecendo informações em tempo real, direcionando ajuda, e facilitando a comunicação entre as vítimas e os serviços de emergência. Link do projeto no GitHub: https://github.com/victorverdoodt/Disaster-Response-Coordinator"
}

DOCUMENT6 = {
    "title": "Pedro Henrique Meireles Mendonça",
    "content": "Este projeto é um gerador de vídeo sobre backrooms. Ele faz webscrapping da wiki e produz um vídeo usando a ferramenta Gemini para gerar o script. Link do projeto no GitHub: https://github.com/PedroHMeireles2001/BackroomsVideoMakerGemini"
}

DOCUMENT7 = {
    "title": "Luiz Otávio Valenzi Sousa",
    "content": "Este projeto é uma descrição do gosto das pessoas e acontecimentos no mundo automobilístico. Link do projeto no GitHub: https://github.com/lzmodsr/lzmodsr.github.io"
}

DOCUMENT8 = {
    "title": "Bernardo Dutra Lemos",
    "content": "O projeto tem como objetivo analisar arquivos PDF ou TXT do usuário, aprendendo sobre as informações contidas para responder perguntas de forma mais confiável e embasada. Utiliza a técnica denominada RAG, que combina geração de texto com recuperação de informações no campo do Processamento de Linguagem Natural (PLN). Link do projeto no GitHub: https://github.com/bdlemos/Gemini_RAG"
}

DOCUMENT9 = {
    "title": "Jorge Gustavo Nunes Oliveira",
    "content": "Este projeto é um chat que responde com voz sintetizada, desenvolvido para atendimento a pessoas cegas. Link do projeto no GitHub: https://github.com/jgnunes1/chatBot_voz"
}

DOCUMENT10 = {
    "title": "Edison Esequiel dos Santos",
    "content": "Este projeto é um simples chat bot. Link do projeto no GitHub: https://github.com/esequielsantos/ediBot/tree/main"
}

DOCUMENT11 = {
    "title": "Rafael Alcantara de Oliveira",
    "content": "Este chatbot utiliza inteligência artificial para ajudar a encontrar versículos da Bíblia a partir de frases ou palavras-chave. Link do projeto no GitHub: https://github.com/zeferdash/Alura-Imersao-IA"
}

DOCUMENT12 = {
    "title": "Gabriel Vilela Carvalho de Souza",
    "content": "O projeto 'PassAki' utiliza IA para gerar um guia turístico com base no CEP digitado pelo usuário. Utiliza APIs para obter informações como latitude, longitude e clima, que ajudam a fornecer dados precisos para o guia. Link do projeto no GitHub: https://github.com/Dev-ilela/PassAKI"
}

DOCUMENT13 = {
    "title": "Rodrigo Alexandre",
    "content": "O projeto 'Scooby-Doo, cade você?' é uma resposta tecnológica para pets em tragédias ambientais. As devastadoras enchentes de 2024 no Rio Grande do Sul deslocaram muitos animais de seus lares. Utiliza um chatbot de WhatsApp integrado ao modelo Gemini de IA da Google para reunir animais perdidos com seus tutores, acelerando o processo de reencontro e aumentando a precisão dos matches. Link do projeto no GitHub: https://github.com/narradorww/pet-rescue-gemini"
}

DOCUMENT14 = {
    "title": "Rafael",
    "content": "Este projeto é um chat que ajuda usuários a estudar para o vestibular. Link do projeto no GitHub: https://github.com/BAT333/Chat-gemini"
}

DOCUMENT15 = {
    "title": "Eris Braggi",
    "content": "Este projeto envolve um chatbot, hospedado neste link do GitHub: https://github.com/erisbraggi/chatbottest/blob/main/Untitled0.ipynb"
}

DOCUMENT16 = {
    "title": "Teofilo Fabio Macedo",
    "content": "Este projeto utiliza inteligência artificial para conectar pessoas que desejam ajudar cidades do Rio Grande do Sul afetadas por desastres naturais. Link do projeto no GitHub: https://github.com/teomacedo/integracao_api_gemini_lista_ongs/"
}

DOCUMENT17 = {
    "title": "Naomi Cristina do Lago",
    "content": "O Diver é um chatbot que integra o Gemini com LangChain e ChromaDB, permitindo conversas que simulam interação direta com a autora do blog naomilago.com. Link do projeto no GitHub: https://github.com/naomilago/diver"
}

DOCUMENT18 = {
    "title": "Valdirene da Paixão Sousa",
    "content": "Projeto que faz uso do Google Gemini. Detalhes adicionais podem ser encontrados no LinkedIn: https://www.linkedin.com/in/valdirene-paixão-617a483b?utm_source=share&utm_campaign=share_via&utm_content=profile&utm_medium=android_app"
}

DOCUMENT19 = {
    "title": "Gilberto Hideaki Matsunaga",
    "content": "Este projeto é um tradutor de Japonês/Português que utiliza IA. Link do projeto no GitHub: https://github.com/gmatsuna/alura_imersao_gemini_ia"
}

DOCUMENT20 = {
    "title": "Giovanna da Silva de Oliveira",
    "content": "Este projeto foca na detecção do uso de edição em imagens, verificando se foram criadas por IA, editadas digitalmente ou estão inalteradas. Link do projeto no GitHub: https://github.com/Giovanna-de-Oliveira/Portifolio/tree/main/Imagem%20Fake%20Natty"
}

DOCUMENT21 = {
    "title": "Fernando Jorge Cavalcante Gomes Filho",
    "content": "Lupus é uma ferramenta que analisa a UX/UI de designs utilizando IA para fornecer feedback instantâneo sobre suas forças e fraquezas. Link do projeto no GitHub: https://github.com/nandowastaken/lupus?tab=readme-ov-file"
}

DOCUMENT22 = {
    "title": "Marcos A. Guerrieri",
    "content": "Este projeto utiliza IA para interpretar receitas médicas escritas, mesmo aquelas com caligrafias ilegíveis, identificando medicamentos, posologia e forma de administração. O sistema informa ao paciente sobre a indicação do medicamento para validar a interpretação do modelo. Link do projeto no GitHub: https://github.com/Guerrieri-vix/gemini_projetcts"
}

DOCUMENT23 = {
    "title": "Luis Fonseca",
    "content": "Chatbot de Planejamento de Viagem com Gemini API: Este projeto desenvolve um chatbot inteligente que auxilia os usuários no planejamento de suas viagens, usando a API Gemini para personalizar sugestões de destinos, voos, hospedagem, atividades e roteiros. O chatbot oferece uma experiência de interação conversacional personalizada, adaptando-se às preferências e orçamento dos usuários. Link do projeto no GitHub: https://github.com/LuisFonsecaPT/imers-oprojetoschatbots.git"
}

DOCUMENT24 = {
    "title": "Guilherme Vieira Alves",
    "content": "IA para Concursos Públicos: Aprimorando o Conhecimento e Aumentando as Chances de Aprovação: Este projeto visa ajudar candidatos a concursos públicos, usando IA para gerar prompts de estudo personalizados, analisar editais, e identificar lacunas de conhecimento. O modelo BERT é usado para uma geração de conteúdo relevante e personalizado. Link do projeto no GitHub: https://github.com/gvaguilherme21/IA-para-Concursos/blob/main/Solução_para_estudo_de_concursos.ipynb"
}

DOCUMENT25 = {
    "title": "Dennis Flores de Souza",
    "content": "MaterI.A.: Assistente pessoal para professores universitários para a criação de questões de múltipla escolha para avaliações, usando conversação com o chat para coletar dados como nome do curso, tipo de questão, e temática. Link do projeto no GitHub: https://github.com/denethesos/ImersaoIA_Alura_Aula4"
}

DOCUMENT26 = {
    "title": "Tiago Ngana Chimbassi",
    "content": "Plataforma de ajuda humanitária. (Detalhes adicionais sobre o projeto não foram fornecidos.) Link do projeto no GitHub: https://github.com/"
}

DOCUMENT27 = {
    "title": "Renato da Silva Teodósio",
    "content": "projeto_automa-o_dba_oracle. (Detalhes adicionais sobre o projeto não foram fornecidos.) Link do projeto no GitHub: https://github.com/renatoteods77"
}

DOCUMENT28 = {
    "title": "Murilo Neves de Martins",
    "content": "Gemini Desafio Game: Jogo simples onde é feita uma pergunta sobre um lugar e o jogador deve descobrir quais são os itens mais comuns encontrados nesse lugar. Link do projeto no GitHub: https://github.com/MuriloNM/Gemini_Desafio_Game_1"
}

DOCUMENT29 = {
    "title": "Luis Henrique dos Santos",
    "content": "Transcritor de áudio utilizando API Gemini e Colab. Link do projeto no GitHub: https://github.com/lhsluis/TranscreveAudio/"
}

DOCUMENT30 = {
    "title": "Fabio Curtis Volpe",
    "content": "GeminiLerRemedio: Pequeno projeto em Python que utiliza o Gemini para identificar remédio por meio de imagem. Link do projeto no GitHub: https://github.com/fabiocurtisvolpe/geminiLerRemedio"
}

DOCUMENT31 = {
    "title": "Pedro Henrique da Costa Santos",
    "content": "Desafio de Saúde do Chatbot: Inteligência artificial que oferece suporte e informações sobre saúde de maneira interativa e personalizada, realizando triagem de sintomas e fornecendo dados sobre saúde. Link do projeto no GitHub: https://github.com/Peedrohenrique/chatbot-saude-desafio-aluraI-gemini"
}

DOCUMENT32 = {
    "title": "Rafael Ruzzante de Campos",
    "content": "Gerador de imagem utilizando o Gemini. Link do projeto no GitHub: https://github.com/rosante/Desafio_Alura_Imersao_Gemini"
}

DOCUMENT33 = {
    "title": "Vinicius Pereira Mateus Borges",
    "content": "TuPy: Tutor avançado de Python para concursos públicos e certificações. Link do projeto no GitHub: https://github.com/Borgesvpm/tupy"
}

DOCUMENT34 = {
    "title": "Pedro Baruch",
    "content": "DesafioAlura-Gemini: Utiliza o Gemini para criar uma experiência imersiva e interativa com personagens únicos e universos ricos. Link do projeto no GitHub: https://github.com/Pedro-Baruch/DesafioAlura-Gemini/tree/main"
}

DOCUMENT35 = {
    "title": "Henrique Ribeiro Moreira",
    "content": "Virtual Friend: Um amigo virtual que oferece suporte emocional e ajuda a explorar sentimentos, com respostas personalizadas e atividades relaxantes. Link do projeto no GitHub: https://github.com/HenriqueRib/virtual_friend_bot"
}

DOCUMENT36 = {
    "title": "Esequiel Santos",
    "content": "ediBot: Simple ChatBot for a TI business site. Link do projeto no GitHub: https://github.com/esequielsantos/ediBot"
}

DOCUMENT37 = {
    "title": "Erick Caique Santos Souza",
    "content": "SOS-RS-Gemini: Chatbot multifuncional para WhatsApp e Telegram, facilitando doações durante desastres naturais. Link do projeto no GitHub: https://github.com/leckliss/sos-rs-gemini/tree/main"
}

DOCUMENT38 = {
    "title": "Leandro Luis da Silva",
    "content": "CMS com BlazorServer: Facilita o compartilhamento de páginas. Link do projeto no GitHub: https://github.com/Leandro01832/Cms_com_BlazorServer.git"
}

DOCUMENT39 = {
    "title": "Gabriel Bastos Sandim",
    "content": "Fake News Detector: Script Python que usa a API GenAI para detectar notícias falsas. Link do projeto no GitHub: https://github.com/gabrielbsandim/fake-news-detector"
}

DOCUMENT40 = {
    "title": "Laysa Maria Nascimento Alves",
    "content": "MedGrandma.ai: Utiliza IA para identificar e descrever medicamentos por imagem, oferecendo recomendações importantes para uso. Link do projeto no GitHub: https://github.com/laysaalves/medgrandma-ai"
}

DOCUMENT41 = {
    "title": "Eduardo Maroja",
    "content": "GeminiRPG: Jogo de RPG de fantasia inspirado em Dungeons and Dragons e ZORG, jogado com comandos via linguagem natural, simulando a experiência com um Mestre humano. Link do projeto no GitHub: https://github.com/dudumaroja/GeminiRPG/tree/main"
}

DOCUMENT42 = {
    "title": "João Vitor Takata Murakawa Okuyama",
    "content": "Projeto IA Agricultura de Precisão: Chatbot que aplica conhecimentos de agricultura de precisão, incluindo análise do terreno via imagem de satélite, para fornecer informações sobre o índice de vegetação e sugerir práticas agrícolas adequadas. Link do projeto no GitHub: https://github.com/takatonto/Projeto_IA_Agricultura_de_Precisao"
}

DOCUMENT43 = {
    "title": "Adriana Sgorlon Maia",
    "content": "IA Aplicada na Prospecção de Clientes: Utiliza IA para direcionar anúncios com filtros específicos para alcançar clientes potenciais."
}

DOCUMENT44 = {
    "title": "Diego Micael Ferreira",
    "content": "Chatbot para atendimentos a usuários de serviços prestados pela Polícia Civil de Minas Gerais. Link do projeto no GitHub: https://github.com/diegomicael/Imersao-IA-Alura"
}

DOCUMENT45 = {
    "title": "Lucas Lemke Saunitti",
    "content": "Assistente ao gestor para organizar reuniões, oferecendo dicas e insights importantes. Link do projeto no GitHub: https://github.com/lucas-saunitti-dev/Alura-AI-Immersion-Project"
}

DOCUMENT46 = {
    "title": "Jaqueline Guimarães da Silva",
    "content": "Desenvolvimento de um Ecossistema de Cuidados de Saúde Integrados - Aplicativo CuidaBem. Link do projeto: https://www.notion.so/Ol-eu-sou-a-Jaqueline-Guimar-es-8f61ebd4ed5b4fb2b53aaeae574c7c03"
}

DOCUMENT47 = {
    "title": "Vinícius Azevedo de Lima",
    "content": "Developer LLM: Auxiliar os desenvolvedores de qualquer linguagem utilizando inteligência artificial para criação e avaliação de código. Link do projeto no GitHub: https://github.com/azvin98/Developer_LLM"
}

DOCUMENT48 = {
    "title": "Edwillie Cardoso",
    "content": "O que comer hoje? Usando a inteligência artificial para encontrar receitas baseadas em listas de ingredientes. Inspirado nas mães que precisam de ajuda para elaborar cardápios. Link do projeto no GitHub: https://github.com/Edwillie/imersao_ia_alura"
}

DOCUMENT49 = {
    "title": "Leonardo Pereira Costa",
    "content": "Projeto voltado para ajudar pessoas a transcrever áudios para texto, pensando nas pessoas surdas. Link do projeto no GitHub: https://github.com/leolpc21/audio_texto"
}

DOCUMENT50 = {
    "title": "Michelli",
    "content": "Chatbot aprendido na aula 4 da imersão, apenas buscando reter conteúdo, fixar e treinar os comandos. Link do projeto no GitHub: https://github.com/MiLaureano/Imersao-IA-Google-Alura/blob/main/Untitled0.ipynb"
}

DOCUMENT51 = {
    "title": "Adriano José Dias Xavier",
    "content": "LegalMindAI: Plataforma avançada que utiliza IA para oferecer insights sobre questões judiciais e processos legais, projetada para profissionais do direito, estudantes e interessados. Link do projeto no GitHub: https://github.com/AdrianoJDXavier/LegalMindAI"
}

DOCUMENT52 = {
    "title": "José Augusto Soares de Moura",
    "content": "Pequena forma de interação com a função chat e com função para limpar o histórico de conversas. Link do projeto no GitHub: https://github.com/josemoura212/alura_ia"
}

DOCUMENT53 = {
    "title": "Adiel Ribeiro do Vale Junior",
    "content": "RPG Master: Transforma o Gemini em um mestre de RPG que gera a aventura dinamicamente conforme os feedbacks do jogador. Link do projeto no GitHub: https://github.com/adielribeiro/RPG_Master_Projeto_Imersao_Aula4"
}

DOCUMENT54 = {
    "title": "Adriano Gaiotto de Oliveira",
    "content": "Gerar roteiro de viagem com seu estilo. Link do projeto no GitHub: https://github.com/sangomax/Roteiro_de_Viagem_com_seu_Estilo/tree/main"
}

DOCUMENT55 = {
    "title": "Ismael Rekovvsky de Souza",
    "content": "Voice Navigation Prototype: API focada na navegação dentro de aplicações por meio da voz, permitindo executar ações e enviar dados conforme a necessidade, também melhorando a acessibilidade. Link do projeto no GitHub: https://github.com/IsmaelRK/Voice-Navigation-Prototype"
}

DOCUMENT56 = {
    "title": "Bruno Urccella Wiss",
    "content": "Assistente de Busca de Hospitais para Casos de Dengue: Este projeto cria um chatbot que ajuda usuários a encontrar hospitais próximos que atendem casos de dengue, usando um LLM para gerar respostas personalizadas. Link do projeto no GitHub: https://github.com/wissbruno/ProjetoImersaoIA"
}

DOCUMENT57 = {
    "title": "Emanoel Ribeiro da Silva",
    "content": "Utilizou o Google IA e o Visual Studio para implementar um site. Link do projeto no GitHub: https://github.com/Noel20052006/Meu-site-2024"
}

DOCUMENT58 = {
    "title": "Roan Ferreira",
    "content": "NerdFit: Aplicação web que motiva programadores e aficionados pela cultura nerd a superar o sedentarismo com treinos personalizados e lembretes motivacionais via WhatsApp. Link do projeto no GitHub: https://github.com/roanfersa/NerdFit"
}

DOCUMENT59 = {
    "title": "Gabriel Bastos Sandim",
    "content": "Blocking Offensive Messages: Script que usa o LLM Gemini para analisar e bloquear mensagens ofensivas. Link do projeto no GitHub: https://github.com/gabrielbsandim/blocking-offensive-messages"
}

DOCUMENT60 = {
    "title": "Jean Rafael do Nascimento Calistro",
    "content": "GeMedic - Sua AI médica para triagem de diagnósticos: Oferece triagem médica remota e informações educativas sobre saúde e prevenção de doenças. Link do projeto no GitHub: https://github.com/calistr0/GeMedic-Diagnostico-medico"
}

DOCUMENT61 = {
    "title": "Marcelo Fernandes da Silva",
    "content": "Chat RH - Automação para Direcionamento de Carreira. Link do projeto no GitHub: https://github.com/marcelosi10/Desafio_IA_Google_Gemini"
}

DOCUMENT62 = {
    "title": "Pedro César Padre Lima",
    "content": "Um programa que permite conversas entre máquina e pessoa por meio de prompts criados durante a imersão. Link do projeto no GitHub: https://github.com/PCLima-404/ProjetoImes-o4.git"
}

DOCUMENT63 = {
    "title": "Aline da Rocha Cardoso",
    "content": "Jogo de conhecimento Imersão Alura + Google. (Detalhes adicionais sobre o projeto não foram fornecidos.)"
}

DOCUMENT64 = {
    "title": "Carlos Humberto Brasileiro Toscano",
    "content": "Analisador de resultado de exame de laboratório com IA. Link do projeto no GitHub: https://github.com/humbertobrasileiro/aula4-imersao-python-ia/blob/main/README.md"
}

DOCUMENT65 = {
    "title": "André Gustavo Xavier dos Santos",
    "content": "Este projeto permite aos usuários converter arquivos de áudio em texto de forma rápida e precisa, e fazer perguntas abertas com respostas informativas da IA Gemini. Link do projeto no GitHub: https://github.com/andregustavoxs/transcricao-audio.git"
}

DOCUMENT66 = {
    "title": "John Silva",
    "content": "IA responsiva baseada no jogo 'Pedra, Papel e Tesoura'. A cada três rodadas, a IA aumenta seu nível de eficiência e responsividade. Link do projeto no GitHub: https://github.com/JohnAS96/Project_Imersao_IA"
}

DOCUMENT67 = {
    "title": "Edison Esequiel",
    "content": "ediBot: Um bot com inteligência artificial que serve como API de chat para sites, detectando a hora do dia para fornecer uma saudação inicial adequada e dialogar conforme a loja específica. Configurável para qualquer empresa. Link do projeto no GitHub: https://github.com/esequielsantos/ediBot"
}

DOCUMENT68 = {
    "title": "Revisor de Código Automático",
    "content": "Revisor de código automático que valida código de programação com base em regras de boas práticas, ajudando a reduzir o tempo de revisão e a quantidade de erros humanos. Link do projeto no GitHub: https://github.com/ezambomsantana/code_reviewer_alura_ai_challenge"
}

DOCUMENT69 = {
    "title": "Marcos Valério de Almeida Nunes",
    "content": "My Next Read: Aplicação que sugere novas leituras com base nos seus 5 livros favoritos usando a API do Gemini para analisar gostos literários. Link do projeto no GitHub: https://github.com/marcosnunesmbs/mynextread"
}

DOCUMENT70 = {
    "title": "Aline da Rocha Cardoso",
    "content": "Jogo do Conhecimento: Um jogo de quiz implementado em Python que testa o conhecimento do jogador, mostrando a resposta correta após cada questão. Link do projeto no GitHub: https://github.com/arctecnologia/IA_Alura-Google/blob/main/Jogo_de_conhecimento_Imersão_Alura_%2B_Google.ipynb"
}

DOCUMENT71 = {
    "title": "Allan Maciel Gomes Galvao",
    "content": "Chatbot de Guia de Estudos Personalizado: Um assistente de estudos que adapta um plano de estudos conforme suas metas e preferências. O código foi desenvolvido no Colab. Link do projeto no GitHub: https://github.com/allanti/gemini_chat/tree/main"
}

DOCUMENT72 = {
    "title": "James William de Melo",
    "content": "Leitor de notas em PDF que converte o conteúdo em JSON, otimizando a adição de novos layouts de notas fiscais. Testado com invoices americanas. Link do projeto no GitHub: https://github.com/jamesmelo/ProjetoGemini"
}

DOCUMENT73 = {
    "title": "Maicon Edson",
    "content": "ChatBot FakeNews: Um projeto baseado em IA para detectar fake news em textos ou links, promovendo análise crítica das notícias. Link do projeto no GitHub: https://github.com/maiconVegas/ChatBot_FakeNews"
}

DOCUMENT74 = {
    "title": "Walner de Assis Passos",
    "content": "Buscando Hotéis Adaptados para PCD: Um chat que auxilia na busca de hotéis com instalações adaptadas para pessoas com deficiência, fornecendo informações detalhadas dos estabelecimentos. Link do projeto no GitHub: https://github.com/Walner-DS/Desafio-Gemini-Alura"
}

DOCUMENT75 = {
    "title": "Leonardo Rocha Rodrigues",
    "content": "Plataforma de aconselhamento de carreira para estudantes, oferecendo informações detalhadas sobre diversas carreiras e auxiliando nas escolhas profissionais. Link do projeto no GitHub: https://github.com/oLeonardo-R/Projetos-Individuais/tree/main/Criando%20chatbot%20com%20a%20Gemini%20API"
}

DOCUMENT76 = {
    "title": "Adriano Xavier",
    "content": "Gemini Suggestions: Uma extensão VSCode que usa IA para analisar código e sugerir melhorias, compatível com várias linguagens de programação. Link do projeto no GitHub: https://github.com/AdrianoJDXavier/gemini-suggestions"
}

DOCUMENT77 = {
    "title": "Luciane de Castro",
    "content": "Projeto que analisa dados de mulheres atletas e gera insights para desenvolvimento econômico no esporte feminino, usando dados coletados através de um Google Forms. Link do projeto no GitHub: https://github.com/lucianedecastro/Projeto_Imersao_Alura_Google/tree/main"
}

DOCUMENT78 = {
    "title": "Kleverton Tayson Dos Santos Bomfim",
    "content": "Tradução e síntese de fala em tempo real com IA Gemini, potencialmente adaptável a dispositivos de implantes cocleares. Link do projeto no GitHub: https://github.com/TaysonTy/Tub"
}

DOCUMENT79 = {
    "title": "Tainá Leandra Dreissig",
    "content": "Projeto Aza: Assistente Virtual Médica e Inteligente que utiliza a API do Gemini para fornecer diagnósticos diferenciados e informações médicas atualizadas. Link do projeto no GitHub: https://github.com/TainaDr/assisteSaude_apiGemini"
}

DOCUMENT80 = {
    "title": "Adilmar Coelho Dantas",
    "content": "Michelzinho: Um chatbot IA que auxilia pessoas com Transtorno do Espectro Autista (TEA) no desenvolvimento de habilidades sociais e emocionais. Link do projeto no GitHub: https://github.com/Adilmar/Michelzinho-Gemini"
}

DOCUMENT81 = {
    "title": "Camila Alves",
    "content": "Chatbot cabeleireiro especializado em cortes de cabelo para jogadores de futebol, utilizando a API do Google Generative AI para gerar respostas personalizadas. Link do projeto no GitHub: https://github.com/alvescamila87/google_AI/blob/main/google_alura_projeto_corte_jogador.ipynb"
}

DOCUMENT82 = {
    "title": "Weber Alves Braga",
    "content": "Jogo da Velha com IA: Um jogo da velha desenvolvido para entreter pessoas entediadas, com uma IA desafiadora. Link do projeto no GitHub: https://github.com/weberBraga/JogoDaVelha?tab=readme-ov-file#readme"
}

DOCUMENT83 = {
    "title": "David Duarte Muniz",
    "content": "Criação de um chatboot interativo com informações sobre polvos e todas as espécies existentes, integrado a um site sobre o mesmo assunto. Link do projeto no GitHub: https://github.com/DavidDuarteMuniz/imersaoaluraula4"
}

DOCUMENT84 = {
    "title": "Cleobeto Junior",
    "content": "Ementário Gemini: Um prompt criado com Google IO Studio que auxilia na análise da probabilidade de aproveitamento de disciplina em cursos, usando IA para comparar ementas. Link do projeto no GitHub: https://github.com/jrmesquita7/ementario_gemini/"
}

DOCUMENT85 = {
    "title": "Gustavo Mitsuyuki Waku",
    "content": "Chatbot financeiro que monta planos de recuperação ou investimento e seus respectivos OKRs para atingir resultados financeiros desejados. Link do projeto no GitHub: https://github.com/gustavomwk/coach_financeiro"
}

DOCUMENT86 = {
    "title": "Claudio Meira Antonio",
    "content": "Chatbot Assistente de Finanças com Google Gemini Pro: Lê PDFs de guias de finanças, extrai informações relevantes, e usa essas informações para interagir com o usuário. Link do projeto no GitHub: https://github.com/upcarreira/Meu-Portfolio/tree/8b09bd145cc361533ed90f1bf8af08da6758df0f/Analise%20e%20Ciencia%20de%20Dados/ChatBot"
}

DOCUMENT87 = {
    "title": "Wellington Francisco Benicio",
    "content": "GeminiWell - Seu Assistente de Bem-Estar. (Detalhes adicionais sobre o projeto não foram fornecidos.) Link do projeto no GitHub: https://github.com/wellington0407/geminiwell"
}

DOCUMENT88 = {
    "title": "Antonio Aparecido Medeiros Santana",
    "content": "Matemática Para Todos: Utiliza a AI Gemini-1.0-pro do Google para responder e explicar resoluções de exercícios de matemática passo-a-passo. Link do projeto no GitHub: https://github.com/antoniomedeiross/matematica_para_todos"
}

DOCUMENT89 = {
    "title": "Luis Emidio",
    "content": "Strigi: Assistente de inteligência artificial gratuito que opera dentro da linha de comando, ajudando com várias tarefas relacionadas a comandos. Link do projeto no GitHub: https://github.com/neogaialab/strigi"
}

DOCUMENT90 = {
    "title": "Bruno da Silva",
    "content": "AjudaOSul.AI: Combate a fraudes em pedidos de ajuda durante crises climáticas no Rio Grande do Sul, usando um chatbot com IA. Link do projeto no GitHub: https://github.com/bruninho-design/AjudaOSul.AI-ImersaoAlura/"
}

DOCUMENT91 = {
    "title": "Carlos César Carissimi Araldi",
    "content": "Criar um chatbot que utiliza a IA do GEMINI para descrever imagens em tempo real, ajudando pessoas com deficiência visual a ter acesso a informações visuais. Link do projeto no GitHub: https://github.com/Carlos5456/Imersao_IA"
}

DOCUMENT92 = {
    "title": "José Rodolfo de Andrade Teixeira",
    "content": "Chatbot auxiliar de estudos de Enfermagem, fornecendo uma ferramenta abrangente especializada no cuidado de pessoas. Link do projeto no GitHub: https://github.com/JoseRAndrade/Repo_Class_4/tree/main"
}

DOCUMENT93 = {
    "title": "Ruan Jefferson dos Santos",
    "content": "ChatBot sobre Futebol. (Detalhes adicionais sobre o projeto não foram fornecidos.) Link do projeto no GitHub: https://github.com/ruanruinas/CHATBOT_FUTEBOL-IMERS-O.ALURA"
}

DOCUMENT94 = {
    "title": "Joel dos Santos de Moraes",
    "content": "Calculadora de Juros Simples e Compostos e seus montantes, desenvolvida para ajudar pessoas leigas a calcular taxas de forma simples e rápida. Link do projeto no GitHub: https://github.com/JoelMoraes77/Aula_4_Projeto_Calculadora/tree/main"
}

DOCUMENT95 = {
    "title": "Paulo Henrique Barboza Filho",
    "content": "NPC Studio: Ferramenta que usa a IA do Gemini para criar NPCs envolventes e memoráveis para campanhas de RPG. Link do projeto no GitHub: https://github.com/AshSlake/NPC-Studio-Com-IA-Gemini/tree/main"
}

DOCUMENT96 = {
    "title": "Leandro Tenorio Perea",
    "content": "Ajuda ao contato com psicólogo através de uma triagem básica via chatbot. Link do projeto no GitHub: https://github.com/LeandroTPerea/Projeto-ALURA/tree/main"
}

DOCUMENT97 = {
    "title": "Gabriel Zanelato",
    "content": "Mergulhe no Mundo Olímpico com o Chatbot Esportivo: Explore a história e curiosidades das Olimpíadas e Paraolimpíadas com um chatbot. Link do projeto no GitHub: https://github.com/GaahZanelato/Bot_Olimpiadas/tree/main"
}

DOCUMENT98 = {
    "title": "YURI BATISTA NOVAES GOIANA FERRAZ",
    "content": "Análise de imagens de plantas para identificar problemas e pragas, sugerindo ações corretivas. Link do projeto no GitHub: https://github.com/ybngf/Saudedaplanta"
}

DOCUMENT99 = {
    "title": "Luis Emidio",
    "content": "Lusci: Bot do Discord para reprodução de música com comandos em linguagem natural, projetado para aprimorar a experiência musical em servidores. Link do projeto no GitHub: https://github.com/neogaialab/lusci"
}

DOCUMENT100 = {
    "title": "Mauricio Canali Xavier",
    "content": "Experiência enriquecedora na Imersão IA 2ª edição da Alura, com aplicação prática no local de trabalho e grandes resultados obtidos. Link do projeto no GitHub: https://github.com/mauriciocanalixavier/projeto_aulura_aula_04/blob/main/pojeto_do__mcx.ipynb"
}

DOCUMENT101 = {
    "title": "Weslley Joaquim Gomes",
    "content": "Bot do Telegram para tradução rápida de textos, áudios e imagens em inglês, facilitando a comunicação entre usuários. Link do projeto no GitHub: https://github.com/weslleyjoaquim/bot-tradutor"
}

DOCUMENT102 = {
    "title": "Charles Douglas de Oliveira",
    "content": "Gerador automático de um plano de negócios para Flutter/Dart. (Detalhes adicionais sobre o projeto não foram fornidos.) Link do projeto no GitHub: https://github.com/charlesdevoliveira/Imersao_Alura_geracao_model"
}

DOCUMENT103 = {
    "title": "Eduardo Souza Franco",
    "content": "Chatbot de atendimento para restaurante, melhorando a experiência do cliente. Link do projeto no GitHub: https://github.com/EduardoFranco10/Chatbot-Restaurante/blob/43ebc16bfc47cea2cbc432503ea35ee94a06c3b8/LICENSE"
}

DOCUMENT104 = {
    "title": "Marcos Henrique",
    "content": "ASA (Apresente-se Alura): Um projeto que utiliza IA para analisar e extrair informações de conversas armazenadas em arquivos de texto. Link do projeto no GitHub: https://github.com/wwwmhcom/apresente-se_alura"
}

DOCUMENT105 = {
    "title": "Ana Alice de Moraes Rodrigues",
    "content": "História de uma garota que viaja aos Estados Unidos em busca de seus sonhos e trabalha na perícia criminal. (Detalhes adicionais sobre o projeto não foram fornecidos.)"
}

DOCUMENT106 = {
    "title": "Cristiano da Silva Xavier",
    "content": "MulherSegura: Projeto inicial para elaboração de Boletim de Ocorrência de Violência Doméstica com descrição das partes e dos fatos. Link do projeto no GitHub: https://github.com/cristianosx/MulherSegura"
}

DOCUMENT107 = {
    "title": "Sílvio Garbes Lara",
    "content": "AluraGeminiAppPersonagens: App que lista personagens de desenhos infantis e permite interação com eles através de um chat. Desenvolvido usando a ferramenta low code Outsystems. Link do projeto no GitHub: https://github.com/silviogarbes/AluraGeminiAppPersonagens/"
}

DOCUMENT108 = {
    "title": "Guilherme Dotorivo de Sousa",
    "content": "Auxiliador De Programadores: Um projeto que facilita a vida do programador, permitindo fazer perguntas, analisar códigos, revisar erros e pedir dicas durante os estudos. Link do projeto no GitHub: https://github.com/gDotorivo/Auxiliador-De-Programadores"
}

DOCUMENT109 = {
    "title": "Gabriel Bastos Sandim",
    "content": "Care My Plants: Um projeto Python que usa o modelo Gemini para fornecer informações sobre cuidados com plantas com base em imagens. Link do projeto no GitHub: https://github.com/gabrielbsandim/care-my-plants"
}

DOCUMENT110 = {
    "title": "Robson Freitas",
    "content": "Desafio Alura: Um chat que interage com conteúdo de arquivos PDF para diversos contextos como educação e suporte ao cliente. Link do projeto no GitHub: https://github.com/RrobsonFreitas/Desafio_Alura"
}

DOCUMENT111 = {
    "title": "Allyson Santos",
    "content": "Edital Scan: Scanner de editais para busca e extração das informações mais relevantes. Link do projeto no GitHub: https://github.com/css-allyson/edital_scan"
}

DOCUMENT112 = {
    "title": "Felipe Moreira Ramos",
    "content": "VIRAL HIT! Utiliza IA generativa para identificar clipes em vídeos longos do YouTube, facilitando a criação de conteúdo engajante. Link do projeto no GitHub: https://github.com/FelipeMoreiraRamos/portifolio-imersao-ia_"
}

DOCUMENT113 = {
    "title": "Bruno Urccella Wiss",
    "content": "MediMap: Assistente virtual que ajuda a encontrar hospitais para casos de dengue, oferecendo um caminho rápido e informações detalhadas sobre os hospitais. Link do projeto no GitHub: https://github.com/wissbruno/ProjetoImersaoIA"
}

DOCUMENT114 = {
    "title": "Leonardo Dias Diene",
    "content": "Transforme sua visão em roteiro com o poder da IA! Um chatbot criador de roteiros personalizados para escritores e cineastas. Link do projeto no GitHub: https://github.com/diasdiene/Crie-o-seu-Pr-prio-Roteiro/blob/main/Untitled8.ipynb"
}

DOCUMENT115 = {
    "title": "Monica Macedo Costa",
    "content": "ColorHappiness Analyzer: Ferramenta que analisa imagens de ambientes e determina a influência das cores na transmissão de felicidade. Ideal para decoradores de interiores. Link do projeto no GitHub: https://github.com/monicamacedocost/ColorHappiness-Analyzer/tree/main"
}

DOCUMENT116 = {
    "title": "Érique Rangel",
    "content": "CHECK RECALL PENDENTE: Determina o nível de gravidade de recalls informados por montadoras de veículos, ajudando empresas a gerenciar recalls pendentes eficientemente. Link do projeto no GitHub: https://github.com/eriquerf/CHECK_RECALL_PENDENTE"
}

DOCUMENT117 = {
    "title": "Érique Rangel Fortes",
    "content": "CHECK RECALL PENDENTE: Similar ao projeto anterior, ajuda empresas a gerenciar recalls de veículos de forma eficaz, classificando-os por gravidade. Link do projeto no GitHub: https://github.com/eriquerf/CHECK_RECALL_PENDENTE"
}

DOCUMENT118 = {
    "title": "Abner",
    "content": "VirtualDoctor: Um assistente virtual que ajuda pessoas interessadas em TI a ingressar ou avançar na área, oferecendo caminhos e dicas. Link do projeto no GitHub: https://github.com/SmAbner/Chat_Bot_Gemini_Ia/blob/main/Untitled3.ipynb"
}

DOCUMENT119 = {
    "title": "Bruno Gonçalves",
    "content": "Sistema de detecção de 'Roubo de Carga'. (Detalhes adicionais sobre o projeto não foram fornecidos.) Link do projeto no GitHub: https://github.com/brunogon17/imersao_ia"
}

DOCUMENT120 = {
    "title": "Davi Oliveira",
    "content": "Cálculo Planetário: Calcula peso e idade em cada planeta do Sistema Solar e expectativa de vida baseada na rotação de cada planeta. Link do projeto no GitHub: https://github.com/IndioguaraniAristoteles?tab=repositories"
}

DOCUMENT121 = {
    "title": "Fabio Closel Faria",
    "content": "Encontre o presente perfeito: Um chatbot de IA que sugere presentes personalizados com base nas características do presenteado e no orçamento disponível. Link do projeto no GitHub: https://github.com/Cod-Tec/gift-chatbot/blob/main/Presente_Perfeito.ipynb"
}

DOCUMENT122 = {
    "title": "Felício Rocha",
    "content": "Assistant for Data Science Projects (ADSP): Um assistente alimentado por IA que auxilia na criação de projetos de ciência de dados. Link do projeto no GitHub: https://github.com/Felicio-Rocha/DS_Portfolio_Assitente/tree/main"
}

DOCUMENT123 = {
    "title": "Emanoel Dlugokenski",
    "content": "Ombro IAmigo: Um ambiente virtual de IA focado em oferecer técnicas de consciência mental para melhorar a saúde mental e emocional dos usuários. Link do projeto no GitHub: https://github.com/emanoeldlugo/Ombro_IAmigo"
}

DOCUMENT124 = {
    "title": "Lucas Pinheiro Rocha",
    "content": "Mecânico Virtual: Auxilia no diagnóstico automotivo com IA, fornecendo possíveis causas, soluções sugeridas e preços de peças necessárias. Link do projeto no GitHub: https://github.com/fullStackLucas/PROJETO_IMERSAO_ALURA/blob/main/Lucas_Gemini_Project_Alura.ipynb"
}

DOCUMENT125 = {
    "title": "Allan Maciel Gomes Galvão",
    "content": "Inclusion Chat: Um chatbot para auxiliar pessoas com deficiência e familiares em questões variadas, desde adaptações físicas até questões psicológicas. Link do projeto no GitHub: https://github.com/allanti/inclusion_chat"
}

DOCUMENT126 = {
    "title": "Matheus Ferreira",
    "content": "Conheça sua vaga: Um sistema que analisa requisitos de vagas de emprego e sugere o que estudar para se qualificar. Link do projeto no GitHub: https://github.com/MatheusMABF/ProjetoImersao"
}

DOCUMENT127 = {
    "title": "Mateus Lima",
    "content": "Planejador de Viagens Inteligente: Um aplicativo que cria roteiros personalizados usando React Native, Expo e IA Gemini. Link do projeto no GitHub: https://github.com/limamateus/GeminiReactNative"
}

DOCUMENT128 = {
    "title": "Vinicius Soares Xavier",
    "content": "Dieta Equilibrada: Retorna uma dieta equilibrada de proteínas e uma lista de compras semanal com base no peso do usuário, usando IA para criar um plano nutricional personalizado. Link do projeto no GitHub: https://github.com/vinxavier/imersao-ia-dieta-equilibrada"
}

DOCUMENT129 = {
    "title": "Christian Bueno",
    "content": "Passeio virtual pela cidade de São Paulo: Um tour virtual que explora pontos turísticos de São Paulo, narrado pelo Gemini, oferecendo curiosidades e descrições detalhadas dos trajetos e destinos. Link do projeto no GitHub: https://github.com/zNexTage/Passeio-virtual-pela-cidade-de-Sao-Paulo/tree/main"
}

DOCUMENT130 = {
    "title": "Vinicius Soares Xavier",
    "content": "Dieta Equilibrada: Retorna uma dieta equilibrada de proteínas e uma lista de compras semanal com base no peso do usuário, usando IA para criar um plano nutricional personalizado. Link do projeto no GitHub: https://github.com/vinxavier/imersao-ia-dieta-equilibrada"
}

DOCUMENT131 = {
    "title": "Paulo Henrique Lerbach Rodrigues",
    "content": "ScoliPal: Um Raio de Esperança - Uma ferramenta de apoio para famílias lidando com escoliose, oferecendo informações confiáveis e análises de imagens de raio-x. Link do projeto no GitHub: https://github.com/palerique/scoliosis_llm"
}

DOCUMENT132 = {
    "title": "Vinicius Tavares da Silva",
    "content": "Job AI Match: Um sistema que analisa currículos e vagas para oferecer feedback personalizado, ajudando a encontrar o emprego ideal. Link do projeto no GitHub: https://github.com/Vinicius-Tavares-Silva/Job-AI-Match"
}

DOCUMENT133 = {
    "title": "Fernando Moretto Ignacio",
    "content": "Travel Planner: Um assistente virtual de viagens que sugere destinos e roteiros com base nas preferências do usuário, oferecendo um serviço de planejamento personalizado. Link do projeto no GitHub: https://github.com/femoig/travel-planner"
}

DOCUMENT134 = {
    "title": "Thales Everardo Albuquerque Reis",
    "content": "Be my eye: Um sistema de análise de conteúdo visual e emocional para auxiliar pessoas com deficiência visual em situações de risco, usando a IA Gemini. Link do projeto no GitHub: https://github.com/thaleseab/ImersaoAluraGoogleGemini/tree/main/Projeto"
}

DOCUMENT135 = {
    "title": "Francisco Costa Silva",
    "content": "Projeto 2024 imersão: Uma experiência de aprendizado impactada por condições físicas do usuário. (Detalhes adicionais sobre o projeto não foram fornecidos.) Link do projeto no GitHub: https://github.com/FraNcs01/projeto-4-aula/blob/ae0f1c6645f57b26a632cd917359a76d67a61160/Projeto%202024%20imersão.ipynb"
}

DOCUMENT136 = {
    "title": "Lucas Miranda da Silva",
    "content": "Mesa Compartilhada: Um projeto/campanha que visa ajudar pessoas em situações de rua e crise, usando um ChatBot para conectar doadores com ONGs confiáveis. Link do projeto no GitHub: https://github.com/LucasMiranda7/projetoMesa_Compartilhada"
}


documents = [DOCUMENT1, DOCUMENT2, DOCUMENT3, DOCUMENT4, DOCUMENT5, DOCUMENT6, DOCUMENT7, DOCUMENT8, DOCUMENT9, DOCUMENT10, DOCUMENT11, DOCUMENT12, DOCUMENT13, DOCUMENT14, DOCUMENT15, DOCUMENT16, DOCUMENT17, DOCUMENT18, DOCUMENT19, DOCUMENT20, DOCUMENT21, DOCUMENT22, DOCUMENT23, DOCUMENT24, DOCUMENT25, DOCUMENT26, DOCUMENT27, DOCUMENT28, DOCUMENT29, DOCUMENT30, DOCUMENT31, DOCUMENT32, DOCUMENT33, DOCUMENT34, DOCUMENT35, DOCUMENT36, DOCUMENT37, DOCUMENT38, DOCUMENT39, DOCUMENT40, DOCUMENT41, DOCUMENT42, DOCUMENT43, DOCUMENT44, DOCUMENT45, DOCUMENT46, DOCUMENT47, DOCUMENT48, DOCUMENT49, DOCUMENT50, DOCUMENT51, DOCUMENT52, DOCUMENT53, DOCUMENT54, DOCUMENT55, DOCUMENT56, DOCUMENT57, DOCUMENT58, DOCUMENT59, DOCUMENT60, DOCUMENT61, DOCUMENT62, DOCUMENT63, DOCUMENT64, DOCUMENT65, DOCUMENT66, DOCUMENT67, DOCUMENT68, DOCUMENT69, DOCUMENT70, DOCUMENT71, DOCUMENT72, DOCUMENT73, DOCUMENT74, DOCUMENT75, DOCUMENT76, DOCUMENT77, DOCUMENT78, DOCUMENT79, DOCUMENT80, DOCUMENT81, DOCUMENT82, DOCUMENT83, DOCUMENT84, DOCUMENT85, DOCUMENT86, DOCUMENT87, DOCUMENT88, DOCUMENT89, DOCUMENT90, DOCUMENT91, DOCUMENT92, DOCUMENT93, DOCUMENT94, DOCUMENT95, DOCUMENT96, DOCUMENT97, DOCUMENT98, DOCUMENT99, DOCUMENT100, DOCUMENT101, DOCUMENT102, DOCUMENT103, DOCUMENT104, DOCUMENT105, DOCUMENT106, DOCUMENT107, DOCUMENT108, DOCUMENT109, DOCUMENT110, DOCUMENT111, DOCUMENT112, DOCUMENT113, DOCUMENT114, DOCUMENT115, DOCUMENT116, DOCUMENT117, DOCUMENT118, DOCUMENT119, DOCUMENT120, DOCUMENT121, DOCUMENT122, DOCUMENT123, DOCUMENT124, DOCUMENT125, DOCUMENT126, DOCUMENT127, DOCUMENT128, DOCUMENT129, DOCUMENT130, DOCUMENT131, DOCUMENT132, DOCUMENT133, DOCUMENT134, DOCUMENT135, DOCUMENT136]

# %%
df = pd.DataFrame(documents)
df.columns = ['Título', 'Conteúdo']
df
# Out:
#                                 Título  \
# 0                 Erick Prados Pereira
# 1    TouTela sensível ao toquechscreen
# 2                   David Duarte Muniz
# 3          José Augusto Faria de Sousa
# 4                      Victor Verdoodt
# ..                                 ...
# 131          Vinicius Tavares da Silva
# 132           Fernando Moretto Ignacio
# 133   Thales Everardo Albuquerque Reis
# 134              Francisco Costa Silva
# 135             Lucas Miranda da Silva
#
#                                               Conteúdo
# 0    Este projeto é um projeto real que foi feito p...
# 1    Uma aplicação para gerar um roteiro de viagem ...
# 2    Projeto de um site de Biologia com informações...
# 3    Este projeto é um corretor de códigos JAVA, qu...
# 4    O projeto 'Disaster Response Coordinator' é um...
# ..                                                 ...
# 131  Job AI Match: Um sistema que analisa currículo...
# ...

# %%
model = 'models/embedding-001'

# %%
def embed_fn(title, text):
  return genai.embed_content(model=model,
                             content=text,
                             task_type="retrieval_document",
                             title=title)["embedding"]

# %%
df['Embeddings'] = df.apply(lambda row: embed_fn(row['Título'], row['Conteúdo']), axis=1)
df
# Out:
#                                 Título  \
# 0                 Erick Prados Pereira
# 1    TouTela sensível ao toquechscreen
# 2                   David Duarte Muniz
# 3          José Augusto Faria de Sousa
# 4                      Victor Verdoodt
# ..                                 ...
# 131          Vinicius Tavares da Silva
# 132           Fernando Moretto Ignacio
# 133   Thales Everardo Albuquerque Reis
# 134              Francisco Costa Silva
# 135             Lucas Miranda da Silva
#
#                                               Conteúdo  \
# 0    Este projeto é um projeto real que foi feito p...
# 1    Uma aplicação para gerar um roteiro de viagem ...
# 2    Projeto de um site de Biologia com informações...
# 3    Este projeto é um corretor de códigos JAVA, qu...
# 4    O projeto 'Disaster Response Coordinator' é um...
# ..                                                 ...
# 131  Job AI Match: Um sistema que analisa currículo...
# ...

# %%
def gerar_e_buscar_consulta(consulta, base, model):
  embedding_da_consulta = genai.embed_content(model=model,
                                              content=consulta,
                                              task_type="RETRIEVAL_QUERY") ["embedding"]

  produtos_escalares = np.dot(np.stack(df["Embeddings"]), embedding_da_consulta)

  indice = np.argmax(produtos_escalares)
  return df.iloc[indice]["Conteúdo"]

# %%
consulta = "Analise esses 136 projetos e me diga qual deles aparenta ter mais utilidade, mais criatividade e mais eficácia?"

trecho = gerar_e_buscar_consulta(consulta, df, model)
print(trecho)
# Out:
# Projeto 2024 imersão: Uma experiência de aprendizado impactada por condições físicas do usuário. (Detalhes adicionais sobre o projeto não foram fornecidos.) Link do projeto no GitHub: https://github.com/FraNcs01/projeto-4-aula/blob/ae0f1c6645f57b26a632cd917359a76d67a61160/Projeto%202024%20imersão.ipynb

# %%
generation_config = {
  "candidate_count": 1,
  "temperature": 1,
}

# %%
prompt = f"Reescreva esse texto de uma forma como se fosse uma banca julgadora de melhores projetos, sem adicionar informações que não façam parte do texto: {trecho}"

model_2 = genai.GenerativeModel("gemini-1.0-pro",
                                generation_config=generation_config)
response = model_2.generate_content(prompt)
print(response.text)
# Out:
# **Projeto 2024 Imersão**
#
# **Avaliação Inicial**
#
# O projeto **2024 Imersão** apresenta uma ideia promissora para enriquecer a experiência de aprendizado. O foco em como as condições físicas dos usuários impactam essa experiência é uma abordagem inovadora e oportuna.
#
# **Análise de Viabilidade**
#
# Embora o texto não forneça detalhes específicos sobre o projeto, o link para o GitHub oferece espaço para que os avaliadores analisem a viabilidade técnica do mesmo.
#
# **Impacto Potencial**
#
# O projeto tem o potencial de transformar a educação ao personalizar o aprendizado com base nas condições físicas de cada indivíduo. Isso pode ajudar a criar experiências de aprendizado mais inclusivas e eficazes.
#
# **Decisão**
#
# Com base nas informações disponíveis, os avaliadores recomendam a aprovação do projeto **2024 Imersão** para avaliação adicional e possível implementação.
